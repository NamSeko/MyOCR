# %%
import os
import random
import numpy as np
import textwrap
import pandas as pd
from PIL import Image, ImageFont, ImageDraw
from uuid import uuid4
import shutil
from pathlib import Path
import re
import unicodedata

# %% [markdown]
# # Create data

# %%
def render_myanmar_text( 
        text, 
        font_dir="font_myanmar", 
        font_size=20, 
        output_path="output.png", 
        padding=5
    ): 
    font_files = [os.path.join(font_dir, f) for f in os.listdir(font_dir) if f.lower().endswith((".ttf", ".otf"))] 
    if not font_files: raise ValueError("Không tìm thấy font trong thư mục!") 
    chosen_font = random.choice(font_files) 
    font = ImageFont.truetype(chosen_font, font_size) 
    temp_img = Image.new("RGB", (1, 1)) 
    draw = ImageDraw.Draw(temp_img) 
    try: 
        bbox = draw.textbbox((0, 0), text, font=font) 
        text_w = bbox[2] - bbox[0] 
        text_h = bbox[3] - bbox[1] 
    except AttributeError: 
        text_w, text_h = font.getsize(text) 
    img = Image.new("RGB", (text_w + padding, text_h + padding), "white") 
    draw = ImageDraw.Draw(img) 
    draw.text((0, 0), text, font=font, fill="black") 
    img.save(output_path) 
    # print("✔ Render xong với font:", chosen_font) 
    return output_path

# %%
render_myanmar_text("နီပေါငလျင် - လူ ၁၀၀ ကျော်သေဆုံး ၁၀၀ ကျော်ဒဏ်ရာရ", font_dir="../font_myanmar", output_path="sample.png")
# Out:
# ✔ Render xong với font: ../font_myanmar/Aka08-Regular.ttf
# 'sample.png'

# %%
def append_to_txt(file_path, text):
    with open(file_path, "a", encoding="utf-8") as f:
        f.write(text + "\n")

# %%
text_df_dir = "../text_data"
list_paths = [f for f in os.listdir(text_df_dir) if f.endswith(".csv")]
list_paths
# Out:
# ['bbc_burmese_news.csv',
#  'Microbiology.csv',
#  'articles.csv',
#  'rakhine_proverbs.csv',
#  'Agriculture.csv',
#  'Mpox Myanmar.csv']

# %%
df1 = pd.read_csv(f"{text_df_dir}/{list_paths[0]}")
df2 = pd.read_csv(f"{text_df_dir}/{list_paths[1]}")
df3 = pd.read_csv(f"{text_df_dir}/{list_paths[2]}")
df4 = pd.read_csv(f"{text_df_dir}/{list_paths[3]}")
df5 = pd.read_csv(f"{text_df_dir}/{list_paths[4]}")
df6 = pd.read_csv(f"{text_df_dir}/{list_paths[5]}")
df=None
df1 = df1[["title", "description"]]
df2 = df2[["Instruction", "Output"]]
df3 = df3[["headline"]]
df5 = df5[["Instruction", "Output"]]
df6 = df6[["Question", "Answer"]]
df = list(df1['title'])+list(df1['description'])+list(df2["Instruction"])+list(df2["Output"])+list(df3['headline'])+list(df4['proverbs'])+list(df5['Instruction'])+list(df5['Output'])+list(df6['Question'])+list(df6['Answer'])
df = pd.DataFrame(df, columns=["text"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39963 entries, 0 to 39962
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    39963 non-null  object
# dtypes: object(1)
# memory usage: 312.3+ KB

# %%
df_clean = df.drop_duplicates()
# mask = [True if len(f)<=80 else False for f in df_clean["text"]]
# df_fix_len = df_clean[mask]

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 36329 entries, 0 to 39962
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    36329 non-null  object
# dtypes: object(1)
# memory usage: 567.6+ KB

# %%
df_clean.head()
# Out:
#                                                 text
# 0  ဌာနချုပ် လိုင်ဇာအနီး စစ်ကောင်စီ အင်အားတိုးချဲ့...
# 1  နိုဝင်ဘာ ၅ ရက်ထိပ်တန်းသတင်းများ - ပဲခူး၊ မုန်း...
# 2  ဟက်ဇ်ဘိုလာတပ် ဘယ်လောက် အင်အားကြီးလဲ၊ အစ္စရေးနဲ...
# 3  အီလွန်မတ်စ်ခ်ကို  အေအိုင်အကြောင်း ယူကေဝန်ကြီးခ...
# 4    နီပေါငလျင် - လူ ၁၀၀ ကျော်သေဆုံး ၁၀၀ ကျော်ဒဏ်ရာရ

# %%
def clean_text(text):
    text = "".join(ch for ch in text if unicodedata.category(ch)[0] != "C")
    text = text.replace("\t", " ").replace("\n", " ").replace("\r", " ")
    text = re.sub(r"\s+", " ", text)
    text = text.strip()
    return text
def clean_text_strict(text):
    allowed_punct = "၊။-–—:/()[]{}'\""
    result = []
    for ch in text:
        if unicodedata.category(ch)[0] == "C":
            continue
        if ch.isspace():
            result.append(" ")
            continue
        if "\u1000" <= ch <= "\u109F":
            result.append(ch)
            continue
        if ch.isalnum():
            result.append(ch)
            continue
        if ch in allowed_punct:
            result.append(ch)
            continue    
    text = "".join(result)
    text = re.sub(r"\s+", " ", text).strip()
    return text
def create_short_dataset(input_data, max_length=25):
    print(f"🔄 Đang xử lý data -> {max_length} ký tự")
    new_lines = []
    for text in input_data:
        chunks = textwrap.wrap(text, width=max_length, break_long_words=False)
        new_lines.extend(chunks)
    print(f"✅ Đã xử lý data (Số lượng: {len(new_lines)})")
    return new_lines

# %%
text_data = df_clean['text']
text_data = [clean_text_strict(text) for text in text_data]
text_data = create_short_dataset(text_data)
# Out:
# 🔄 Đang xử lý data -> 25 ký tự
# ✅ Đã xử lý data (Số lượng: 152684)

# %%
new_df = pd.DataFrame(text_data, columns=["text"])

# %%
new_df = new_df.drop_duplicates()

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 109607 entries, 0 to 152681
# Data columns (total 1 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   text    109607 non-null  object
# dtypes: object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
df_filtered=new_df
print(f"Data sau khi lọc (<= 25 chars): {len(df_filtered)}")

SAMPLE_SIZE = 30000 
if len(df_filtered) > SAMPLE_SIZE:
    df_final = df_filtered.sample(n=SAMPLE_SIZE, random_state=42)
else:
    df_final = df_filtered

print(f"Data dùng để train thực tế: {len(df_final)}")

train_df, val_df = train_test_split(df_final, test_size=0.1, random_state=42)

print(f"Số lượng Train: {len(train_df)}")
print(f"Số lượng Val:   {len(val_df)}")
# Out:
# Data sau khi lọc (<= 25 chars): 109607
# Data dùng để train thực tế: 30000
# Số lượng Train: 27000
# Số lượng Val:   3000

# %%
def create_data(data_frame, val_mode=False):
    imgs = []
    img_dir = Path("train")
    path = Path("data/train")
    if val_mode:
        path = Path("data/val")
        img_dir = Path("val")
    data = data_frame["text"]
    for label in data:
        img_name = f"{uuid4()}.png"
        imgs.append(img_dir/img_name)
        render_myanmar_text(label, font_dir="../font_myanmar", output_path=path/img_name)
    data_frame["label"] = imgs
    return data_frame

# %%
df_train = create_data(train_df)
# Out:
# ✔ Render xong với font: ../font_myanmar/AkkhayarRobo-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/PT13_PhanteeHandWritten-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/PT13_PhanteeHandWritten-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/SM01_WaTokeLay-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/PT01_PhanTee-Italic.ttf
# ✔ Render xong với font: ../font_myanmar/PT01_PhanTee-Italic.ttf
# ✔ Render xong với font: ../font_myanmar/AkkhayarBrush-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/PT01_PhanTee-Italic.ttf
# ✔ Render xong với font: ../font_myanmar/SM01_WaTokeLay-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/AkkhayarRobo-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/Aka08-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/PT13_PhanteeHandWritten-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/Aka08-Regular.ttf
# ✔ Render xong với font: ../font_myanmar/Aka10-Light.ttf
# ✔ Render xong với font: ../font_myanmar/008.ttf
# ...

# %%
df_val = create_data(val_df, val_mode=True)

# %%
df_train.to_csv("data/train.csv", index=False)
df_val.to_csv("data/val.csv", index=False)

# %%
def create_data_label_txt(file_path, data_frame):
    with open(file_path, "w", encoding="utf-8") as f:
        for _, row in data_frame.iterrows():
            path = row["label"]
            text = row["text"]
            f.write(f"{path}\t{text}\n")
    print("✔ Done! File đã được tạo:", file_path)

# %%
create_data_label_txt("data/train.txt", df_train)
create_data_label_txt("data/val.txt", df_val)
# Out:
# ✔ Done! File đã được tạo: data/train.txt
# ✔ Done! File đã được tạo: data/val.txt

# %% [markdown]
# # Test data for demonstration

# %%
df_train = pd.read_csv("data/train.csv")

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17409 entries, 0 to 17408
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    17409 non-null  object
#  1   label   17409 non-null  object
# dtypes: object(2)
# memory usage: 272.1+ KB

# %%
df_val = pd.read_csv("data/val.csv")
df_val.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7462 entries, 0 to 7461
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    7462 non-null   object
#  1   label   7462 non-null   object
# dtypes: object(2)
# memory usage: 116.7+ KB

# %% [markdown]
# # Check data

# %%
import os

# --- CẤU HÌNH CỦA BẠN ---
label_file = "data/train.txt" 
dict_path = "data/my_en_dict.txt" # Đường dẫn giống trong file config yml của bạn
# ------------------------

# 1. Load từ điển
with open(dict_path, 'r', encoding='utf-8') as f:
    dict_chars = set(line.strip('\n') for line in f.readlines())
dict_chars.add(' ') # Luôn cho phép dấu cách

print(f"Số lượng ký tự trong từ điển: {len(dict_chars)}")

# 2. Check data
valid_count = 0
invalid_count = 0

with open(label_file, 'r', encoding='utf-8') as f:
    lines = f.readlines()

print(f"Tổng số dòng data: {len(lines)}")

for i, line in enumerate(lines):
    parts = line.strip().split('\t')
    if len(parts) < 2: continue
    
    label = parts[1]
    
    # Kiểm tra từng ký tự trong nhãn
    is_valid = True
    missing_chars = []
    for char in label:
        if char not in dict_chars:
            is_valid = False
            missing_chars.append(char)
            
    if is_valid:
        valid_count += 1
    else:
        invalid_count += 1
        if invalid_count <= 5: # Chỉ in 5 lỗi đầu tiên
            print(f"[Dòng {i+1}] Bị loại vì ký tự '{missing_chars}' không có trong Dict.")

print("-" * 30)
print(f"Kết quả: {valid_count} dòng hợp lệ | {invalid_count} dòng bị loại bỏ.")

if valid_count == 0:
    print("❌ LỖI NGHIÊM TRỌNG: 0 dòng dữ liệu hợp lệ. Đây là lý do gây lỗi RecursionError.")
    print("👉 Hãy thay đổi file 'character_dict_path' trong config bao gồm các ký tự bị thiếu.")
else:
    print("✅ Data có vẻ ổn về mặt từ điển.")
# Out:
# Số lượng ký tự trong từ điển: 146
# Tổng số dòng data: 17409
# ------------------------------
# Kết quả: 17409 dòng hợp lệ | 0 dòng bị loại bỏ.
# ✅ Data có vẻ ổn về mặt từ điển.

# %%
import os

# --- CẤU HÌNH ---
label_file_path = "data/train.txt"  # File label của bạn
output_dict_path = "data/my_en_dict.txt" # Nơi lưu file dict mới
# ----------------

print("Đang quét toàn bộ ký tự trong label...")
unique_chars = set()

with open(label_file_path, "r", encoding="utf-8") as f:
    lines = f.readlines()

for line in lines:
    parts = line.strip().split('\t')
    if len(parts) >= 2:
        text = parts[1]
        # Thêm từng ký tự vào set (tự động loại bỏ trùng lặp)
        for char in text:
            unique_chars.add(char)

# Loại bỏ ký tự xuống dòng và khoảng trắng (PaddleOCR tự xử lý space)
if '\n' in unique_chars: unique_chars.remove('\n')
if '\r' in unique_chars: unique_chars.remove('\r')

# Sắp xếp và ghi ra file
sorted_chars = sorted(list(unique_chars))

with open(output_dict_path, "w", encoding="utf-8") as f:
    for char in sorted_chars:
        f.write(char + "\n")

print(f"✅ Đã tạo xong từ điển mới tại: {output_dict_path}")
print(f"✅ Tổng số ký tự: {len(sorted_chars)}")
print("👉 Hãy cập nhật đường dẫn này vào file config .yml ngay!")
# Out:
# Đang quét toàn bộ ký tự trong label...
# ✅ Đã tạo xong từ điển mới tại: data/my_en_dict.txt
# ✅ Tổng số ký tự: 144
# 👉 Hãy cập nhật đường dẫn này vào file config .yml ngay!

# %%
import os

def analyze_ocr_labels(file_path):
    if not os.path.exists(file_path):
        print(f"Lỗi: Không tìm thấy file tại {file_path}")
        return

    lengths = []
    
    print(f"Đang đọc file: {file_path} ...")
    
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                line = line.strip()
                if not line: continue
                
                parts = line.split('\t')
                
                if len(parts) >= 2:
                    label = parts[-1]
                    lengths.append(len(label))
                else:
                    pass
                    
    except Exception as e:
        print(f"Có lỗi khi đọc file: {e}")
        return

    if not lengths:
        print("Không tìm thấy dữ liệu hợp lệ.")
        return

    total_samples = len(lengths)
    max_len = max(lengths)
    avg_len = sum(lengths) / total_samples
    sorted_lens = sorted(lengths)
    
    p90 = sorted_lens[int(0.90 * total_samples)]
    p95 = sorted_lens[int(0.95 * total_samples)]
    p99 = sorted_lens[int(0.99 * total_samples)]

    print("-" * 30)
    print("KẾT QUẢ PHÂN TÍCH")
    print("-" * 30)
    print(f"Tổng số mẫu:      {total_samples}")
    print(f"Độ dài lớn nhất:  {max_len}")
    print(f"Độ dài trung bình:{avg_len:.2f}")
    print("-" * 30)
    print("PHÂN BỐ DỮ LIỆU:")
    print(f"90% dữ liệu có độ dài <= {p90}")
    print(f"95% dữ liệu có độ dài <= {p95}")
    print(f"99% dữ liệu có độ dài <= {p99}")
    print("-" * 30)
    
    count_over_25 = sum(1 for x in lengths if x > 25)
    count_over_50 = sum(1 for x in lengths if x > 50)
    count_over_80 = sum(1 for x in lengths if x > 80)
    
    print(f"Số mẫu > 25 ký tự: {count_over_25} ({count_over_25/total_samples*100:.2f}%)")
    print(f"Số mẫu > 50 ký tự: {count_over_50} ({count_over_50/total_samples*100:.2f}%)")
    print(f"Số mẫu > 80 ký tự: {count_over_80} ({count_over_80/total_samples*100:.2f}%)")

# %%
dataset_path = "data/train.txt" 
analyze_ocr_labels(dataset_path)
dataset_path = "data/val.txt" 
analyze_ocr_labels(dataset_path)
# Out:
# Đang đọc file: data/train.txt ...
# ------------------------------
# KẾT QUẢ PHÂN TÍCH
# ------------------------------
# Tổng số mẫu:      17409
# Độ dài lớn nhất:  80
# Độ dài trung bình:62.14
# ------------------------------
# PHÂN BỐ DỮ LIỆU:
# 90% dữ liệu có độ dài <= 77
# 95% dữ liệu có độ dài <= 79
# 99% dữ liệu có độ dài <= 80
# ------------------------------
# Số mẫu > 25 ký tự: 17328 (99.53%)
# Số mẫu > 50 ký tự: 14111 (81.06%)
# Số mẫu > 80 ký tự: 0 (0.00%)
# Đang đọc file: data/val.txt ...
# ------------------------------
# KẾT QUẢ PHÂN TÍCH
# ------------------------------
# Tổng số mẫu:      7462
# Độ dài lớn nhất:  80
# Độ dài trung bình:62.57
# ------------------------------
# PHÂN BỐ DỮ LIỆU:
# 90% dữ liệu có độ dài <= 78
# 95% dữ liệu có độ dài <= 79
# 99% dữ liệu có độ dài <= 80
# ------------------------------
# Số mẫu > 25 ký tự: 7199 (96.48%)
# Số mẫu > 50 ký tự: 6169 (82.67%)
# Số mẫu > 80 ký tự: 0 (0.00%)
